# %% [markdown]
# # Bitcoin and Ethereum price prediction with RNN LSTM

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
import datetime
import numpy as np
import gc
import warnings
warnings.filterwarnings('ignore')
# import the relevant Keras modules
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Setting up hyper parameters and global variables for our model:

# %%
neurons = 512                 # number of hidden units in the LSTM layer
activation_function = 'tanh'  # activation function for LSTM and Dense layer
loss = 'mse'                  # loss function for calculating the gradient, in this case Mean Squared Error
optimizer= 'adam'             # optimizer for appljying gradient decent
dropout = 0.25                # dropout ratio used after each LSTM layer to avoid overfitting
batch_size = 128              
epochs = 53                  
window_len = 7               # is an intiger to be used as the look back window for creating a single input sample.
training_size = 0.8           # porportion of data to be used for training
merge_date = '2016-01-01'     # the earliest date which we have data for both ETH and BTC or any other provided coin

# %% [markdown]
# Here we will define functions for preprocessing our data as well as the build_model function:

# %%
def get_market_data(market, tag=True):
  """
  market: the full name of the cryptocurrency as spelled on coinmarketcap.com. eg.: 'bitcoin'
  tag: eg.: 'btc', if provided it will add a tag to the name of every column.
  returns: panda DataFrame
  This function will use the coinmarketcap.com url for provided coin/token page. 
  Reads the OHLCV and Market Cap.
  Converts the date format to be readable. 
  Makes sure that the data is consistant by converting non_numeric values to a number very close to 0.
  And finally tags each columns if provided.
  """
  market_data = pd.read_html("https://coinmarketcap.com/currencies/" + market + 
                             "/historical-data/?start=20130428&end="+time.strftime("%Y%m%d"), flavor='html5lib')[0]
  market_data = market_data.assign(Date=pd.to_datetime(market_data['Date']))  
  market_data['Volume'] = (pd.to_numeric(market_data['Volume'], errors='coerce').fillna(0))
  if tag:
    market_data.columns = [market_data.columns[0]] + [tag + '_' + i for i in market_data.columns[1:]]
  return market_data


def merge_data(a, b, from_date=merge_date):
  """
  a: first DataFrame
  b: second DataFrame
  from_date: includes the data from the provided date and drops the any data before that date.
  returns merged data as Pandas DataFrame
  """
  merged_data = pd.merge(a, b, on=['Date'])
  merged_data = merged_data[merged_data['Date'] >= from_date]
  return merged_data


def add_volatility(data, coins=['BTC', 'ETH']):
  """
  data: input data, pandas DataFrame
  coins: default is for 'btc and 'eth'. It could be changed as needed
  This function calculates the volatility and close_off_high of each given coin in 24 hours, 
  and adds the result as new columns to the DataFrame.
  Return: DataFrame with added columns
  """
  for coin in coins:
    # calculate the daily change
    kwargs = {coin + '_change': lambda x: (x[coin + '_Close'] - x[coin + '_Open']) / x[coin + '_Open'],
             coin + '_close_off_high': lambda x: 2*(x[coin + '_High'] - x[coin + '_Close']) / (x[coin + '_High'] - x[coin + '_Low']) - 1,
             coin + '_volatility': lambda x: (x[coin + '_High'] - x[coin + '_Low']) / (x[coin + '_Open'])}
    data = data.assign(**kwargs)
  return data


def create_model_data(data):
  """
  data: pandas DataFrame
  This function drops unnecessary columns and reverses the order of DataFrame based on decending dates.
  Return: pandas DataFrame
  """
  data = data[['Date']+[coin+metric for coin in ['BTC_', 'ETH_'] for metric in ['Close','Volume']]]
  data = data.sort_values(by='Date')
  return data


def split_data(data, training_size=0.8):
  """
  data: Pandas Dataframe
  training_size: proportion of the data to be used for training
  This function splits the data into training_set and test_set based on the given training_size
  Return: train_set and test_set as pandas DataFrame
  """
  return data[:int(training_size*len(data))], data[int(training_size*len(data)):]


def create_inputs(data, coins=['BTC', 'ETH'], window_len=window_len):
  """
  data: pandas DataFrame, this could be either training_set or test_set
  coins: coin datas which will be used as the input. Default is 'btc', 'eth'
  window_len: is an intiger to be used as the look back window for creating a single input sample.
  This function will create input array X from the given dataset and will normalize 'Close' and 'Volume' between 0 and 1
  Return: X, the input for our model as a python list which later needs to be converted to numpy array.
  """
  norm_cols = [coin + metric for coin in coins for metric in ['_Close', '_Volume']]
  inputs = []
  for i in range(len(data) - window_len):
    temp_set = data[i:(i + window_len)].copy()
    inputs.append(temp_set)
    for col in norm_cols:
      inputs[i].loc[:, col] = inputs[i].loc[:, col] / inputs[i].loc[:, col].iloc[0] - 1  
  return inputs


def create_outputs(data, coin, window_len=window_len):
  """
  data: pandas DataFrame, this could be either training_set or test_set
  coin: the target coin in which we need to create the output labels for
  window_len: is an intiger to be used as the look back window for creating a single input sample.
  This function will create the labels array for our training and validation and normalize it between 0 and 1
  Return: Normalized numpy array for 'Close' prices of the given coin
  """
  return (data[coin + '_Close'][window_len:].values / data[coin + '_Close'][:-window_len].values) - 1


def to_array(data):
  """
  data: DataFrame
  This function will convert list of inputs to a numpy array
  Return: numpy array
  """
  x = [np.array(data[i]) for i in range (len(data))]
  return np.array(x)


def build_model(inputs, output_size, neurons, activ_func=activation_function, dropout=dropout, loss=loss, optimizer=optimizer):
  """
  inputs: input data as numpy array
  output_size: number of predictions per input sample
  neurons: number of neurons/ units in the LSTM layer
  active_func: Activation function to be used in LSTM layers and Dense layer
  dropout: dropout ration, default is 0.25
  loss: loss function for calculating the gradient
  optimizer: type of optimizer to backpropagate the gradient
  This function will build 3 layered RNN model with LSTM cells with dripouts after each LSTM layer 
  and finally a dense layer to produce the output using keras' sequential model.
  Return: Keras sequential model and model summary
  """
  model = Sequential()
  model.add(LSTM(neurons, return_sequences=True, input_shape=(inputs.shape[1], inputs.shape[2]), activation=activ_func))
  model.add(Dropout(dropout))
  model.add(LSTM(neurons, return_sequences=True, activation=activ_func))
  model.add(Dropout(dropout))
  model.add(LSTM(neurons, activation=activ_func))
  model.add(Dropout(dropout))
  model.add(Dense(units=output_size))
  model.add(Activation(activ_func))
  model.compile(loss=loss, optimizer=optimizer, metrics=['mae'])
  model.summary()
  return model

# %% [markdown]
# Below are the functions for plotting market data and the results after the training:

# %%
def show_plot(data, tag):
  fig, (ax1, ax2) = plt.subplots(2,1, gridspec_kw = {'height_ratios':[3, 1]})
  ax1.set_ylabel('Closing Price ($)',fontsize=12)
  ax2.set_ylabel('Volume ($ bn)',fontsize=12)
  ax2.set_yticks([int('%d000000000'%i) for i in range(10)])
  ax2.set_yticklabels(range(10))
  ax1.set_xticks([datetime.date(i,j,1) for i in range(2013,2019) for j in [1,7]])
  ax1.set_xticklabels('')
  ax2.set_xticks([datetime.date(i,j,1) for i in range(2013,2019) for j in [1,7]])
  ax2.set_xticklabels([datetime.date(i,j,1).strftime('%b %Y')  for i in range(2013,2019) for j in [1,7]])
  ax1.plot(data['Date'].astype(datetime.datetime),data[tag +'_Close'])
  ax2.bar(data['Date'].astype(datetime.datetime).values, data[tag +'_Volume'].values)
  fig.tight_layout()
  plt.show()
  

def date_labels():
  last_date = market_data.iloc[0, 0]
  date_list = [last_date - datetime.timedelta(days=x) for x in range(len(X_test))]
  return[date.strftime('%m/%d/%Y') for date in date_list][::-1]


def plot_results(history, model, Y_target, coin):
  plt.figure(figsize=(25, 20))
  plt.subplot(311)
  plt.plot(history.epoch, history.history['loss'], )
  plt.plot(history.epoch, history.history['val_loss'])
  plt.xlabel('Number of Epochs')
  plt.ylabel('Loss')
  plt.title(coin + ' Model Loss')
  plt.legend(['Training', 'Test'])

  plt.subplot(312)
  plt.plot(Y_target)
  plt.plot(model.predict(X_train))
  plt.xlabel('Dates')
  plt.ylabel('Price')
  plt.title(coin + ' Single Point Price Prediction on Training Set')
  plt.legend(['Actual','Predicted'])

  ax1 = plt.subplot(313)
  plt.plot(test_set[coin + '_Close'][window_len:].values.tolist())
  plt.plot(((np.transpose(model.predict(X_test)) + 1) * test_set[coin + '_Close'].values[:-window_len])[0])
  plt.xlabel('Dates')
  plt.ylabel('Price')
  plt.title(coin + ' Single Point Price Prediction on Test Set')
  plt.legend(['Actual','Predicted'])
  
  date_list = date_labels()
  ax1.set_xticks([x for x in range(len(date_list))])
  for label in ax1.set_xticklabels([date for date in date_list], rotation='vertical')[::2]:
    label.set_visible(False)

  plt.show()

# %% [markdown]
# Load the market data into variables *btc_data* and *eth_data*:

# %%
btc_data = get_market_data("bitcoin", tag='BTC')
eth_data = get_market_data("ethereum", tag='ETH')

# %%
btc_data.head()
# Out:
#         Date  BTC_Open  BTC_High  BTC_Low  BTC_Close    BTC_Volume  \
# 0 2018-03-25   8612.81   8682.01  8449.10    8495.78  4.569880e+09
# 1 2018-03-24   8901.95   8996.18  8665.70    8668.12  5.664600e+09
# 2 2018-03-23   8736.25   8879.62  8360.62    8879.62  5.954120e+09
# 3 2018-03-22   8939.44   9100.71  8564.90    8728.47  5.530390e+09
# 4 2018-03-21   8937.48   9177.37  8846.33    8929.28  6.043130e+09
#
#    BTC_Market Cap
# 0    145882000000
# 1    150762000000
# 2    147941000000
# 3    151366000000
# 4    151316000000

# %%
show_plot(btc_data, tag='BTC')
show_plot(eth_data, tag='ETH')

# %% [markdown]
# Merging the BTC and ETH data and splitting them to training and test sets:

# %%
market_data = merge_data(btc_data, eth_data)
model_data = create_model_data(market_data)
train_set, test_set = split_data(model_data)

# %%
model_data.head()
# Out:
#           Date  BTC_Close  BTC_Volume  ETH_Close  ETH_Volume
# 814 2016-01-01     434.33  36278900.0   0.948024      206062
# 813 2016-01-02     433.44  30096600.0   0.937124      255504
# 812 2016-01-03     430.01  39633800.0   0.971905      407632
# 811 2016-01-04     433.09  38477500.0   0.954480      346245
# 810 2016-01-05     431.96  34522600.0   0.950176      219833

# %% [markdown]
# Pre-processing data and producing inputs and target outputs:

# %%
train_set = train_set.drop('Date', 1)
test_set = test_set.drop('Date', 1)

X_train = create_inputs(train_set)
Y_train_btc = create_outputs(train_set, coin='BTC')
X_test = create_inputs(test_set)
Y_test_btc = create_outputs(test_set, coin='BTC')

Y_train_eth = create_outputs(train_set, coin='ETH')
Y_test_eth = create_outputs(test_set, coin='ETH')

X_train, X_test = to_array(X_train), to_array(X_test)

print (np.shape(X_train), np.shape(X_test), np.shape(Y_train_btc), np.shape(Y_test_btc))
print (np.shape(X_train), np.shape(X_test), np.shape(Y_train_eth), np.shape(Y_test_eth))
# Out:
# (645, 7, 4) (156, 7, 4) (645,) (156,)
# (645, 7, 4) (156, 7, 4) (645,) (156,)

# %% [markdown]
# Initializing the model and training it for predicting BTC price for next day:

# %%
# clean up the memory
gc.collect()

# random seed for reproducibility
np.random.seed(202)

# initialise model architecture
btc_model = build_model(X_train, output_size=1, neurons=neurons)

# train model on data
btc_history = btc_model.fit(X_train, Y_train_btc, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(X_test, Y_test_btc), shuffle=False)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 7, 512)            1058816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 7, 512)            2099200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 5,257,729
# Trainable params: 5,257,729
# Non-trainable params: 0
# _________________________________________________________________
# Train on 645 samples, validate on 156 samples
# Epoch 1/53
# 645/645 [==============================] - 11s 17ms/step - loss: 0.0095 - mean_absolute_error: 0.0697 - val_loss: 0.0319 - val_mean_absolute_error: 0.1440
# Epoch 2/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0078 - mean_absolute_error: 0.0651 - val_loss: 0.0292 - val_mean_absolute_error: 0.1369
# Epoch 3/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0096 - mean_absolute_error: 0.0757 - val_loss: 0.0255 - val_mean_absolute_error: 0.1288
# Epoch 4/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0067 - mean_absolute_error: 0.0620 - val_loss: 0.0207 - val_mean_absolute_error: 0.1139
# Epoch 5/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0051 - mean_absolute_error: 0.0537 - val_loss: 0.0155 - val_mean_absolute_error: 0.0944
# Epoch 6/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0064 - mean_absolute_error: 0.0587 - val_loss: 0.0148 - val_mean_absolute_error: 0.0925
# Epoch 7/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0068 - mean_absolute_error: 0.0586 - val_loss: 0.0154 - val_mean_absolute_error: 0.0983
# Epoch 8/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0054 - mean_absolute_error: 0.0527 - val_loss: 0.0156 - val_mean_absolute_error: 0.0949
# Epoch 9/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0050 - mean_absolute_error: 0.0524 - val_loss: 0.0126 - val_mean_absolute_error: 0.0871
# Epoch 10/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0041 - mean_absolute_error: 0.0451 - val_loss: 0.0124 - val_mean_absolute_error: 0.0850
# Epoch 11/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0041 - mean_absolute_error: 0.0468 - val_loss: 0.0110 - val_mean_absolute_error: 0.0808
# Epoch 12/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0035 - mean_absolute_error: 0.0420 - val_loss: 0.0108 - val_mean_absolute_error: 0.0788
# Epoch 13/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0039 - mean_absolute_error: 0.0466 - val_loss: 0.0094 - val_mean_absolute_error: 0.0739
# Epoch 14/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0029 - mean_absolute_error: 0.0373 - val_loss: 0.0091 - val_mean_absolute_error: 0.0714
# Epoch 15/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0418 - val_loss: 0.0083 - val_mean_absolute_error: 0.0680
# Epoch 16/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0025 - mean_absolute_error: 0.0349 - val_loss: 0.0081 - val_mean_absolute_error: 0.0664
# Epoch 17/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0026 - mean_absolute_error: 0.0364 - val_loss: 0.0074 - val_mean_absolute_error: 0.0634
# Epoch 18/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - val_loss: 0.0073 - val_mean_absolute_error: 0.0617
# Epoch 19/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0022 - mean_absolute_error: 0.0331 - val_loss: 0.0069 - val_mean_absolute_error: 0.0599
# Epoch 20/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0022 - mean_absolute_error: 0.0325 - val_loss: 0.0069 - val_mean_absolute_error: 0.0600
# Epoch 21/53
# 645/645 [==============================] - 7s 11ms/step - loss: 0.0022 - mean_absolute_error: 0.0337 - val_loss: 0.0066 - val_mean_absolute_error: 0.0586
# Epoch 22/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0022 - mean_absolute_error: 0.0330 - val_loss: 0.0065 - val_mean_absolute_error: 0.0575
# Epoch 23/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0023 - mean_absolute_error: 0.0339 - val_loss: 0.0064 - val_mean_absolute_error: 0.0574
# Epoch 24/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0314 - val_loss: 0.0062 - val_mean_absolute_error: 0.0563
# Epoch 25/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0323 - val_loss: 0.0062 - val_mean_absolute_error: 0.0563
# Epoch 26/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0327 - val_loss: 0.0059 - val_mean_absolute_error: 0.0552
# Epoch 27/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0315 - val_loss: 0.0060 - val_mean_absolute_error: 0.0558
# Epoch 28/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0021 - mean_absolute_error: 0.0329 - val_loss: 0.0057 - val_mean_absolute_error: 0.0544
# Epoch 29/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0315 - val_loss: 0.0057 - val_mean_absolute_error: 0.0546
# Epoch 30/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0310 - val_loss: 0.0057 - val_mean_absolute_error: 0.0540
# Epoch 31/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0320 - val_loss: 0.0055 - val_mean_absolute_error: 0.0544
# Epoch 32/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0326 - val_loss: 0.0053 - val_mean_absolute_error: 0.0525
# Epoch 33/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0310 - val_loss: 0.0052 - val_mean_absolute_error: 0.0527
# Epoch 34/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0309 - val_loss: 0.0056 - val_mean_absolute_error: 0.0544
# Epoch 35/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0023 - mean_absolute_error: 0.0348 - val_loss: 0.0051 - val_mean_absolute_error: 0.0518
# Epoch 36/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0310 - val_loss: 0.0051 - val_mean_absolute_error: 0.0520
# Epoch 37/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0301 - val_loss: 0.0050 - val_mean_absolute_error: 0.0517
# Epoch 38/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0300 - val_loss: 0.0051 - val_mean_absolute_error: 0.0523
# Epoch 39/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0307 - val_loss: 0.0049 - val_mean_absolute_error: 0.0513
# Epoch 40/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0295 - val_loss: 0.0050 - val_mean_absolute_error: 0.0514
# Epoch 41/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0297 - val_loss: 0.0050 - val_mean_absolute_error: 0.0516
# Epoch 42/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0293 - val_loss: 0.0048 - val_mean_absolute_error: 0.0509
# Epoch 43/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0294 - val_loss: 0.0050 - val_mean_absolute_error: 0.0517
# Epoch 44/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0315 - val_loss: 0.0050 - val_mean_absolute_error: 0.0516
# Epoch 45/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0315 - val_loss: 0.0050 - val_mean_absolute_error: 0.0510
# Epoch 46/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0321 - val_loss: 0.0050 - val_mean_absolute_error: 0.0526
# Epoch 47/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0314 - val_loss: 0.0049 - val_mean_absolute_error: 0.0501
# Epoch 48/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0302 - val_loss: 0.0050 - val_mean_absolute_error: 0.0521
# Epoch 49/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0047 - val_mean_absolute_error: 0.0501
# Epoch 50/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0017 - mean_absolute_error: 0.0285 - val_loss: 0.0048 - val_mean_absolute_error: 0.0511
# Epoch 51/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0301 - val_loss: 0.0048 - val_mean_absolute_error: 0.0508
# Epoch 52/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0292 - val_loss: 0.0047 - val_mean_absolute_error: 0.0504
# Epoch 53/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0285 - val_loss: 0.0049 - val_mean_absolute_error: 0.0514

# %% [markdown]
# Plot the results:

# %%
plot_results(btc_history, btc_model, Y_train_btc, coin='BTC')

# %% [markdown]
# Initializing the model and training it for predicting ETH price for next day:

# %%
# clean up the memory
gc.collect()

# random seed for reproducibility
np.random.seed(202)

# initialise model architecture
eth_model = build_model(X_train, output_size=1, neurons=neurons)

# train model on data
eth_history = eth_model.fit(X_train, Y_train_eth, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(X_test, Y_test_eth), shuffle=False)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 7, 512)            1058816
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 7, 512)            2099200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 5,257,729
# Trainable params: 5,257,729
# Non-trainable params: 0
# _________________________________________________________________
# Train on 645 samples, validate on 156 samples
# Epoch 1/53
# 645/645 [==============================] - 45s 70ms/step - loss: 0.0693 - mean_absolute_error: 0.1720 - val_loss: 0.0317 - val_mean_absolute_error: 0.1406
# Epoch 2/53
# 645/645 [==============================] - 7s 11ms/step - loss: 0.0454 - mean_absolute_error: 0.1482 - val_loss: 0.0252 - val_mean_absolute_error: 0.1248
# Epoch 3/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0350 - mean_absolute_error: 0.1262 - val_loss: 0.0156 - val_mean_absolute_error: 0.0961
# Epoch 4/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0238 - mean_absolute_error: 0.1031 - val_loss: 0.0147 - val_mean_absolute_error: 0.0939
# Epoch 5/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0227 - mean_absolute_error: 0.1022 - val_loss: 0.0113 - val_mean_absolute_error: 0.0794
# Epoch 6/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0205 - mean_absolute_error: 0.0935 - val_loss: 0.0114 - val_mean_absolute_error: 0.0794
# Epoch 7/53
# 645/645 [==============================] - 7s 11ms/step - loss: 0.0183 - mean_absolute_error: 0.0878 - val_loss: 0.0099 - val_mean_absolute_error: 0.0717
# Epoch 8/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0165 - mean_absolute_error: 0.0842 - val_loss: 0.0087 - val_mean_absolute_error: 0.0690
# Epoch 9/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0161 - mean_absolute_error: 0.0831 - val_loss: 0.0085 - val_mean_absolute_error: 0.0663
# Epoch 10/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0154 - mean_absolute_error: 0.0794 - val_loss: 0.0080 - val_mean_absolute_error: 0.0661
# Epoch 11/53
# 645/645 [==============================] - 7s 10ms/step - loss: 0.0140 - mean_absolute_error: 0.0757 - val_loss: 0.0074 - val_mean_absolute_error: 0.0616
# Epoch 12/53
# 645/645 [==============================] - 6s 10ms/step - loss: 0.0134 - mean_absolute_error: 0.0741 - val_loss: 0.0070 - val_mean_absolute_error: 0.0598
# Epoch 13/53
# 645/645 [==============================] - 6s 10ms/step - loss: 0.0121 - mean_absolute_error: 0.0709 - val_loss: 0.0068 - val_mean_absolute_error: 0.0582
# Epoch 14/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0119 - mean_absolute_error: 0.0704 - val_loss: 0.0064 - val_mean_absolute_error: 0.0564
# Epoch 15/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0112 - mean_absolute_error: 0.0697 - val_loss: 0.0067 - val_mean_absolute_error: 0.0580
# Epoch 16/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0112 - mean_absolute_error: 0.0683 - val_loss: 0.0062 - val_mean_absolute_error: 0.0570
# Epoch 17/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0111 - mean_absolute_error: 0.0694 - val_loss: 0.0067 - val_mean_absolute_error: 0.0566
# Epoch 18/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0099 - mean_absolute_error: 0.0661 - val_loss: 0.0057 - val_mean_absolute_error: 0.0544
# Epoch 19/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0098 - mean_absolute_error: 0.0652 - val_loss: 0.0059 - val_mean_absolute_error: 0.0528
# Epoch 20/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0105 - mean_absolute_error: 0.0655 - val_loss: 0.0053 - val_mean_absolute_error: 0.0511
# Epoch 21/53
# 645/645 [==============================] - 7s 10ms/step - loss: 0.0096 - mean_absolute_error: 0.0648 - val_loss: 0.0053 - val_mean_absolute_error: 0.0506
# Epoch 22/53
# 645/645 [==============================] - 6s 10ms/step - loss: 0.0094 - mean_absolute_error: 0.0637 - val_loss: 0.0054 - val_mean_absolute_error: 0.0509
# Epoch 23/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0091 - mean_absolute_error: 0.0613 - val_loss: 0.0051 - val_mean_absolute_error: 0.0497
# Epoch 24/53
# 645/645 [==============================] - 5s 8ms/step - loss: 0.0089 - mean_absolute_error: 0.0612 - val_loss: 0.0054 - val_mean_absolute_error: 0.0506
# Epoch 25/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0086 - mean_absolute_error: 0.0629 - val_loss: 0.0050 - val_mean_absolute_error: 0.0501
# Epoch 26/53
# 645/645 [==============================] - 8s 12ms/step - loss: 0.0094 - mean_absolute_error: 0.0628 - val_loss: 0.0051 - val_mean_absolute_error: 0.0476
# Epoch 27/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0088 - mean_absolute_error: 0.0609 - val_loss: 0.0051 - val_mean_absolute_error: 0.0514
# Epoch 28/53
# 645/645 [==============================] - 7s 11ms/step - loss: 0.0092 - mean_absolute_error: 0.0629 - val_loss: 0.0049 - val_mean_absolute_error: 0.0488
# Epoch 29/53
# 645/645 [==============================] - 6s 10ms/step - loss: 0.0095 - mean_absolute_error: 0.0616 - val_loss: 0.0051 - val_mean_absolute_error: 0.0502
# Epoch 30/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0087 - mean_absolute_error: 0.0617 - val_loss: 0.0048 - val_mean_absolute_error: 0.0495
# Epoch 31/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0096 - mean_absolute_error: 0.0623 - val_loss: 0.0053 - val_mean_absolute_error: 0.0502
# Epoch 32/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0090 - mean_absolute_error: 0.0624 - val_loss: 0.0054 - val_mean_absolute_error: 0.0531
# Epoch 33/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0087 - mean_absolute_error: 0.0613 - val_loss: 0.0048 - val_mean_absolute_error: 0.0466
# Epoch 34/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0093 - mean_absolute_error: 0.0630 - val_loss: 0.0048 - val_mean_absolute_error: 0.0507
# Epoch 35/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0086 - mean_absolute_error: 0.0612 - val_loss: 0.0049 - val_mean_absolute_error: 0.0486
# Epoch 36/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0087 - mean_absolute_error: 0.0608 - val_loss: 0.0049 - val_mean_absolute_error: 0.0501
# Epoch 37/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0081 - mean_absolute_error: 0.0585 - val_loss: 0.0047 - val_mean_absolute_error: 0.0478
# Epoch 38/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0091 - mean_absolute_error: 0.0621 - val_loss: 0.0049 - val_mean_absolute_error: 0.0506
# Epoch 39/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0083 - mean_absolute_error: 0.0591 - val_loss: 0.0045 - val_mean_absolute_error: 0.0476
# Epoch 40/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0086 - mean_absolute_error: 0.0598 - val_loss: 0.0047 - val_mean_absolute_error: 0.0489
# Epoch 41/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0082 - mean_absolute_error: 0.0595 - val_loss: 0.0045 - val_mean_absolute_error: 0.0481
# Epoch 42/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0082 - mean_absolute_error: 0.0591 - val_loss: 0.0047 - val_mean_absolute_error: 0.0483
# Epoch 43/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0087 - mean_absolute_error: 0.0587 - val_loss: 0.0048 - val_mean_absolute_error: 0.0494
# Epoch 44/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0092 - mean_absolute_error: 0.0613 - val_loss: 0.0047 - val_mean_absolute_error: 0.0485
# Epoch 45/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0082 - mean_absolute_error: 0.0603 - val_loss: 0.0046 - val_mean_absolute_error: 0.0487
# Epoch 46/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0082 - mean_absolute_error: 0.0576 - val_loss: 0.0047 - val_mean_absolute_error: 0.0496
# Epoch 47/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0084 - mean_absolute_error: 0.0606 - val_loss: 0.0047 - val_mean_absolute_error: 0.0487
# Epoch 48/53
# 645/645 [==============================] - 6s 10ms/step - loss: 0.0082 - mean_absolute_error: 0.0594 - val_loss: 0.0045 - val_mean_absolute_error: 0.0483
# Epoch 49/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0087 - mean_absolute_error: 0.0590 - val_loss: 0.0047 - val_mean_absolute_error: 0.0487
# Epoch 50/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0085 - mean_absolute_error: 0.0587 - val_loss: 0.0046 - val_mean_absolute_error: 0.0488
# Epoch 51/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0082 - mean_absolute_error: 0.0589 - val_loss: 0.0047 - val_mean_absolute_error: 0.0496
# Epoch 52/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0076 - mean_absolute_error: 0.0567 - val_loss: 0.0046 - val_mean_absolute_error: 0.0481
# Epoch 53/53
# 645/645 [==============================] - 6s 9ms/step - loss: 0.0078 - mean_absolute_error: 0.0564 - val_loss: 0.0047 - val_mean_absolute_error: 0.0498

# %%
plot_results(eth_history, eth_model, Y_train_eth, coin='ETH')
